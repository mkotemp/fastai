# %% [markdown]
# <a href="https://colab.research.google.com/github/mkotemp/fastai/blob/main/NEW_MKO's_own_demi_courtney_of_is_it_a_bird_updated_version_dec_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Is it a bird?

# %% [markdown]
# #MKO NOTE 6/16/2024:
# This is a version of 'is it a bird' that works (the version found in the course doesn't run for me). I found this notebook after searching the fast.ai forums. I put a 'mkotemp' to denote where I see there were changes to the code from the original version.

# %%
#NB: Kaggle requires phone verification to use the internet or a GPU. If you haven't done that yet, the cell below will fail
#    This code is only here to check that your internet is enabled. It doesn't do anything else.
#    Here's a help thread on getting your phone number verified: https://www.kaggle.com/product-feedback/135367

import socket,warnings
try:
    socket.setdefaulttimeout(1)
    socket.socket(socket.AF_INET, socket.SOCK_STREAM).connect(('1.1.1.1', 53))
except socket.error as ex: raise Exception("STOP: No internet. Click '>|' in top right and set 'Internet' switch to on")

# %%
# It's a good idea to ensure you're running the latest version of any libraries you need.
# `!pip install -Uqq <libraries>` upgrades to the latest version of <libraries>
# NB: You can safely ignore any warnings or errors pip spits out about running as root or incompatibilities
import os

#mko updated below:
#iskaggle = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '')

#if iskaggle:
# !pip install -U duckduckgo_search
# !pip install fastai
# !pip install fastbook
# Out:
# Requirement already satisfied: duckduckgo_search in /usr/local/lib/python3.10/dist-packages (6.1.7)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from duckduckgo_search) (8.1.7)
# Requirement already satisfied: pyreqwest-impersonate>=0.4.8 in /usr/local/lib/python3.10/dist-packages (from duckduckgo_search) (0.4.8)
# Requirement already satisfied: orjson>=3.10.5 in /usr/local/lib/python3.10/dist-packages (from duckduckgo_search) (3.10.5)
# Requirement already satisfied: fastai in /usr/local/lib/python3.10/dist-packages (2.7.15)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from fastai) (23.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastai) (24.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from fastai) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /usr/local/lib/python3.10/dist-packages (from fastai) (1.5.46)
# Requirement already satisfied: torchvision>=0.11 in /usr/local/lib/python3.10/dist-packages (from fastai) (0.18.0+cu121)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from fastai) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from fastai) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fastai) (2.32.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from fastai) (6.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.10/dist-packages (from fastai) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from fastai) (9.4.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from fastai) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from fastai) (1.11.4)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.10/dist-packages (from fastai) (3.7.5)
# Requirement already satisfied: torch<2.4,>=1.10 in /usr/local/lib/python3.10/dist-packages (from fastai) (2.3.0+cu121)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (4.66.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (2.7.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (67.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->fastai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fastai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fastai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fastai) (2024.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (3.15.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (3.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<2.4,>=1.10->fastai) (12.5.40)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fastai) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fastai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fastai) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fastai) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fastai) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fastai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->fastai) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->fastai) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fastai) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fastai) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<4->fastai) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (2.18.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<4->fastai) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<2.4,>=1.10->fastai) (1.3.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4->fastai) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4->fastai) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (0.1.2)
# Requirement already satisfied: fastbook in /usr/local/lib/python3.10/dist-packages (0.0.29)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from fastbook) (23.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastbook) (24.1)
# Requirement already satisfied: fastai>=2.6 in /usr/local/lib/python3.10/dist-packages (from fastbook) (2.7.15)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from fastbook) (0.20.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from fastbook) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fastbook) (2.32.3)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from fastbook) (4.41.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from fastbook) (2.20.0)
# Requirement already satisfied: ipywidgets<8 in /usr/local/lib/python3.10/dist-packages (from fastbook) (7.7.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from fastbook) (0.1.99)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from fastai>=2.6->fastbook) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /usr/local/lib/python3.10/dist-packages (from fastai>=2.6->fastbook) (1.5.46)
# Requirement already satisfied: torchvision>=0.11 in /usr/local/lib/python3.10/dist-packages (from fastai>=2.6->fastbook) (0.18.0+cu121)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from fastai>=2.6->fastbook) (3.7.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from fastai>=2.6->fastbook) (6.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.10/dist-packages (from fastai>=2.6->fastbook) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from fastai>=2.6->fastbook) (9.4.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from fastai>=2.6->fastbook) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from fastai>=2.6->fastbook) (1.11.4)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.10/dist-packages (from fastai>=2.6->fastbook) (3.7.5)
# Requirement already satisfied: torch<2.4,>=1.10 in /usr/local/lib/python3.10/dist-packages (from fastai>=2.6->fastbook) (2.3.0+cu121)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8->fastbook) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8->fastbook) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8->fastbook) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8->fastbook) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8->fastbook) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8->fastbook) (3.0.11)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets->fastbook) (3.15.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets->fastbook) (1.25.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->fastbook) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->fastbook) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->fastbook) (0.3.8)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets->fastbook) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->fastbook) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->fastbook) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets->fastbook) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->fastbook) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets->fastbook) (0.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->fastbook) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fastbook) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fastbook) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fastbook) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->fastbook) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->fastbook) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->fastbook) (2024.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->fastbook) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->fastbook) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->fastbook) (0.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->fastbook) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->fastbook) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->fastbook) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->fastbook) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->fastbook) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->fastbook) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets->fastbook) (4.12.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (4.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->fastbook) (1.16.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai>=2.6->fastbook) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai>=2.6->fastbook) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai>=2.6->fastbook) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai>=2.6->fastbook) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai>=2.6->fastbook) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai>=2.6->fastbook) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai>=2.6->fastbook) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai>=2.6->fastbook) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai>=2.6->fastbook) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai>=2.6->fastbook) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai>=2.6->fastbook) (0.12.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai>=2.6->fastbook) (2.7.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai>=2.6->fastbook) (3.1.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4->fastai>=2.6->fastbook) (3.4.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai>=2.6->fastbook) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai>=2.6->fastbook) (3.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai>=2.6->fastbook) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai>=2.6->fastbook) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai>=2.6->fastbook) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai>=2.6->fastbook) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai>=2.6->fastbook) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai>=2.6->fastbook) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai>=2.6->fastbook) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai>=2.6->fastbook) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai>=2.6->fastbook) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai>=2.6->fastbook) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai>=2.6->fastbook) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch<2.4,>=1.10->fastai>=2.6->fastbook) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<2.4,>=1.10->fastai>=2.6->fastbook) (12.5.40)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (6.5.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fastai>=2.6->fastbook) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fastai>=2.6->fastbook) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fastai>=2.6->fastbook) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fastai>=2.6->fastbook) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fastai>=2.6->fastbook) (3.1.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fastai>=2.6->fastbook) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fastai>=2.6->fastbook) (3.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8->fastbook) (0.8.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<4->fastai>=2.6->fastbook) (1.2.0)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8->fastbook) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.13)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai>=2.6->fastbook) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai>=2.6->fastbook) (2.18.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai>=2.6->fastbook) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai>=2.6->fastbook) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai>=2.6->fastbook) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai>=2.6->fastbook) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<4->fastai>=2.6->fastbook) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<2.4,>=1.10->fastai>=2.6->fastbook) (1.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (4.2.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4->fastai>=2.6->fastbook) (1.2.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (4.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (3.0.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4->fastai>=2.6->fastbook) (1.14.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (0.1.2)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8->fastbook) (1.2.1)

# %% [markdown]
# In 2015 the idea of creating a computer system that could recognise birds was considered so outrageously challenging that it was the basis of [this XKCD joke](https://xkcd.com/1425/):

# %% [markdown]
# But today, we can do exactly that, in just a few minutes, using entirely free resources!
#
# The basic steps we'll take are:
#
# 1. Use DuckDuckGo to search for images of "bird photos"
# 1. Use DuckDuckGo to search for images of "forest photos"
# 1. Fine-tune a pretrained neural network to recognise these two groups
# 1. Try running this model on a picture of a bird and see if it works.

# %% [markdown]
# ## Step 1: Download images of birds and non-birds

# %%
from fastbook import *
from fastai.vision.widgets import *

#mko note: this code is using 'search_images_ddg', rather than 'ddg_images'
#mko note: return L(ddg_images(term, max_results=max_images)).itemgot('image')
def search_images(term, max_images=30):
    print(f"Searching for '{term}'")
    return L(search_images_ddg(term, max_images=max_images))

# %% [markdown]
# Let's start by searching for a bird photo and seeing what kind of result we get. We'll start by getting URLs from a search:

# %%
#NB: `search_images` depends on duckduckgo.com, which doesn't always return correct responses.
#    If you get a JSON error, just try running it again (it may take a couple of tries).
urls = search_images('demi moore photos', max_images=1)
urls[0]
# Out:
# Searching for 'demi moore photos'
# 'http://www.hawtcelebs.com/wp-content/uploads/2014/11/demi-moore-at-2014-lacma-art-film-gala-in-los-angeles_1.jpg'

# %% [markdown]
# ...and then download a URL and take a look at it:

# %%
from fastdownload import download_url
dest = 'demi_moore.jpg'
download_url(urls[0], dest, show_progress=False)

from fastai.vision.all import *
im = Image.open(dest)
im.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=171x256>

# %% [markdown]
# Now let's do the same with "forest photos":

# %%
download_url(search_images('courtney cox photos', max_images=1)[0], 'courtney_cox.jpg', show_progress=False)
Image.open('courtney_cox.jpg').to_thumb(256,256)
# Out:
# Searching for 'courtney cox photos'
# <PIL.Image.Image image mode=RGB size=186x256>

# %% [markdown]
# Our searches seem to be giving reasonable results, so let's grab a few examples of each of "bird" and "forest" photos, and save each group of photos to a different folder (I'm also trying to grab a range of lighting conditions here):

# %%
searches = 'courtney cox','demi moore'
path = Path('demimoore_or_not')
from time import sleep

for o in searches:
    dest = (path/o)
    dest.mkdir(exist_ok=True, parents=True)
    download_images(dest, urls=search_images(f'{o} photo'))
    sleep(10)  # Pause between searches to avoid over-loading server
    download_images(dest, urls=search_images(f'{o} sun photo'))
    sleep(10)
    download_images(dest, urls=search_images(f'{o} shade photo'))
    sleep(10)
    resize_images(path/o, max_size=400, dest=path/o)
# Out:
# Searching for 'courtney cox photo'
# Searching for 'courtney cox sun photo'
# Searching for 'courtney cox shade photo'
# Searching for 'demi moore photo'
# Searching for 'demi moore sun photo'
# Searching for 'demi moore shade photo'

# %% [markdown]
# #MKO NOTE 6/16/2024:
#
# this one next section of code was added to the original notebook by the revisioner. It doesn't contribute to the program working...it just adds additional feedback for the person running the code.

# %%
print(path)
searches = 'courtney cox','demi moore'

for imageType in searches:
    print(imageType)
    content = os.listdir(path/imageType)
    for element in content:
        print(element)
# Out:
# demimoore_or_not
# courtney cox
# f1f68714-7cf5-45b8-9921-17fb390074b8.jpg
# e7083f09-1d89-4015-838b-ce4961d213e3.jpg
# 554c4d34-1f55-4ce4-be1c-2a7c4625aae7.jpg
# 04e84807-33f9-4243-bd81-8a7c7b94af87.jpg
# 4c16ec11-7ca1-4d55-b98d-b2111d31bc73.jpg
# a310addd-1365-4282-9c35-868f8604d4a3.jpg
# 418da7fe-05b2-4fef-bd1a-4dac5317c9ed.jpg
# 292e9740-2514-45da-9c32-65bcd2126521.jpg
# 6d813722-fff4-4375-bdb7-92a63c7a02c8.jpg
# b27f7781-b8ae-4a72-a720-6cc252d622fc.jpeg
# 64a0f062-1531-4387-bf75-6111dba13e7b.jpg
# 48387be4-1fb1-403b-8d8d-5860adbba266.jpg
# 6d325a5a-043c-4537-b683-caf272e2a1e7.jpg
# acb9c1b1-8eab-4ad5-891b-fd54f992ced4.jpg
# ae756aae-224c-4fcd-b28a-8d604bd5cb1e.jpg
# d791384a-849e-40b2-8aff-e4f21a148beb.jpg
# af9c9f07-f07b-4809-b054-fb9ec99fc026.jpg
# d2bc1b2d-d5b5-4b01-8db1-e13afc408bf7.jpg
# c27c2463-bf22-40fb-bc1c-e6000df74bee.jpg
# 37a73c18-4516-42e8-b8f4-7883ffa487d2.jpg
# 506c9233-460e-4c82-965c-4160d601dd94.jpg
# 719515ea-fc79-403b-9fe9-8c99e2743cfe.jpg
# fabd42b7-19dd-41eb-94f0-6bdd0e16e76a.jpg
# faf9559d-4ec3-4371-ab5e-1f3b2ef868bd.jpg
# e772d377-f95a-46bb-9ee2-a2a0767999c4.jpg
# b7a92b32-b54a-489f-93c0-cd16ae071d47.jpg
# 8fdb2b21-ff66-4d3a-8bc2-c8dab8f6084e.jpg
# 8ccb0ca1-d825-4394-97ac-74ad2d1d9d22.jpg
# 7a81e34f-5a5b-439b-bc3e-9a33f461c138.jpg
# 50850406-a6cd-401e-8d93-97d0787f6fba.jpg
# 18ccaffa-a836-44c2-a7ee-cb6c98351528.png
# a4082626-8a12-4c93-94d0-e186812b3e22.jpg
# cc779785-c884-469d-acda-edd4d86aebf7.jpg
# cf6ddc6a-2400-4593-8781-debe16cd9f2d.jpg
# 2411b1e4-d62e-4a73-a76d-7b325a1f9d0e.jpeg
# e5cb486f-c097-412b-8aaf-21f94bddfbae.jpg
# 174a1451-2f6d-49fa-8e06-b9a48b724222.jpg
# f5eaffef-7956-4dde-9bf3-60f28404af3a.jpg
# 5ba46a85-e6d4-4c92-9c81-ea5d59b428d6.jpg
# e28c469a-00d5-4ce2-8347-4b5c7f0ec947.jpg
# 0e996246-e057-4101-b762-ccbb3afb8a01.jpg
# 1367f95c-c0a9-4b5a-b6b8-b88c1315aadf.jpg
# 9e1d6fd7-d662-4f51-8d3e-e3126b04a962.jpg
# b681b608-8d6a-4ab9-afbc-c18d6fb0bc7d.jpg
# ffeade4a-68ab-4927-92bb-84560808abc4.jpg
# 8934b8bf-e795-41b9-bb9a-667e6bb4dd04.jpg
# 15dde841-bbb9-42bf-89c7-a0010649a126.jpg
# 4e4f1d0a-2c35-4282-8af5-235a56829a65.jpg
# 9344fe6b-3cf0-4406-8983-469274c23395.jpg
# 89f85ca9-dc61-4bc1-88de-cdc2927780a9.jpg
# f25d2b82-1673-41db-8468-00352f38fa29.jpg
# 58c62d7a-e711-4745-b773-f68cee847578.jpg
# 942ee4c3-a1e2-4ee9-8b02-8603ee564eb1.jpg
# 15db8f0c-8a1c-4bda-8bbb-8371b45e4f07.jpg
# 1fca2241-5175-41a5-b054-fd8bd22c3127.jpg
# 2558ebe8-be25-4530-9452-634976eac3ae.jpg
# 1115446d-6ef8-42ec-89a0-2fc4cba211e8.jpg
# 7e06a604-6c45-4bfd-917a-114232f10a4f.jpg
# 6e034d8b-2c57-41b0-a15c-8136aba15de2.jpg
# 4ed06690-a659-43ac-8489-8e969da737ef.jpg
# a1717e4c-e769-400f-b9e6-ea1ab66aae59.jpg
# 81810d99-54ed-4e20-87b1-c032f7fb7cfa.jpg
# cdf59f34-f022-4937-abb5-29bce28bbe0e.webp
# ce1954d3-4f5e-4ce1-84db-20920e3be3d1.jpg
# c56dcf34-ac8c-42d2-9a8b-4da1ed1382a5.jpg
# 2e1efecf-c01d-4e03-b6ab-cd4d6e68ecde.jpg
# 9e247de5-d385-4939-bcf9-3d4bcb5b73a3.jpg
# 8879085d-2cb8-45fc-bda9-c3f346526e33.jpg
# 0617e6e1-2c4f-496b-9607-c1e21a88236a.jpg
# a45d3369-eaf9-4a96-89b4-f0446a597bdb.jpeg
# b6da6a00-6c2c-4b4d-b76e-44251719e54d.jpg
# 52d7641a-9aef-4d82-8e27-7ac49250e242.jpg
# 99859125-db5f-48cc-b6ea-93f2f88c4087.jpg
# 0ff0bbe6-a549-46d3-a249-a86d0682124d.jpg
# c8c07c05-d09d-437b-8ae1-c5aecc03f32c.jpg
# bcd976a7-7855-42bd-a5ee-6092d191a99d.jpg
# 7f46e191-b508-42eb-adf4-7aad0ad1ec76.jpg
# f16286b8-46cb-4d9d-86a4-ffa30fa02503.jpg
# 4652808b-4978-4637-b4e0-f4c4f3c5fdbb.jpg
# 43c52442-c451-470a-ac45-14c984a870b2.jpg
# da2b72fc-80c6-4afc-997b-b5aade7df1a2.jpg
# f44397d5-fb06-43c7-af8f-5bf331d65a0f.jpg
# cde20774-ea6f-4211-9234-367564d6cb43.jpg
# fcee123c-12d8-4522-b9c2-582de088b5ed.jpg
# 5903decb-7a8f-43c4-b05f-86e933058aba.jpg
# fb8bf27a-4228-4adb-8fbd-03bee04fd128.jpg
# 08ff718a-e899-4fa5-a9ca-fb8132e338e5.jpg
# ca86b969-6561-457c-80ec-f37475104eb3.jpg
# e4d7facc-8e89-402e-8954-0db5e95100b3.jpg
# 5a556c8b-2b8e-4214-b987-52237a1d5c70.jpg
# ee33ca7e-4058-45a1-b16c-d849a8bec614.jpg
# 35cc1a78-72e8-4ae7-ac94-74b24c9299b6.jpg
# 7a1c1fbd-0740-48f8-a952-86762e7cf5ca.jpg
# 07951cd0-431c-4231-954f-9001c4d2ca8c.jpg
# 7eeea3bb-7328-42a2-8a31-5bb09cb4858a.jpg
# c9390848-cff8-440c-9582-1e38495c7c74.jpg
# 3bd759a1-312c-4472-a8c2-5887dfd73dd5.jpg
# eaa2f06c-f107-4d6d-9294-6ae7838be2ee.jpg
# 25c3e1b7-e6d3-4dd9-ae3a-ae214ae8ceb2.jpg
# 51cc51e4-b65a-4a78-9ac8-cc74e8924672.jpg
# f9739a36-01ee-4d94-92c2-f516f5b2b564.jpg
# 5db1f610-e821-4f08-9929-5682059c7a1f.jpg
# 9a734ebd-699e-4f31-aa75-9bbd95349591.jpg
# 390eff37-6295-45fb-aa08-6cc90b78c290.jpg
# 302550cf-5df2-45c6-bb44-44bff3880ae0.jpg
# 0c41bc43-2638-4d2e-aba3-979b83581517.jpg
# fb87efe4-c6dd-48d9-b47b-c7ba9a8c9f42.jpg
# 3f8607b2-1a70-4da9-9a5b-29199708c410.jpg
# e7bf8111-0286-4925-9b2f-2a7fdf23d73f.jpg
# b1b7b97d-2390-430d-8d5f-c25ea18f7c67.jpg
# 77f90f20-59ab-4f08-996c-54a12cbf3109.jpg
# d00cefc0-5d6b-4028-be47-a8339c3af4cc.jpg
# c317af02-9158-4d6d-a20d-4c5e9cf38fcb.jpg
# b9d04b28-f553-4ec9-a1a1-d8437308435f.jpg
# 4d8b3456-6333-4aef-9c15-f670d6163094.jpg
# ef8073e6-86fa-4520-b3ae-cdb209f48d19.jpg
# cd01e967-9a1d-44b8-bf26-34ab45f163d5.jpg
# a175a476-b13a-4216-9ba4-0e2e62b4f5a2.jpg
# 27dbbfb5-4b48-497f-ba33-c4c71c3ae4fa.jpg
# ba132009-96c0-4243-b950-223edd171b71.jpg
# 7a77be64-b403-48ac-a542-b4abcd978fa6.jpg
# 49fa1d87-d0bc-4049-89bd-5c76086f0142.jpg
# 7ceccf5a-f687-49d2-b530-6bdf3bf07657.jpg
# 205be2e2-71d5-49f0-9491-35e0ad6cb9ef.jpg
# 7bef13ad-8080-4825-b643-962d8f1f86d1.jpg
# 200555ea-b812-4c86-aac0-363b683c029f.jpg
# 6944234f-fedc-49ff-9635-f6b173a41579.jpg
# 859733fa-2530-46dc-be04-47017a7444bd.jpg
# 1de54072-f603-48d6-aafe-2e2b36635819.jpg
# 004c37e3-1e6d-461b-b401-626f87c51a94.jpg
# 0e65031e-522a-4163-abf7-2dc380dd8c08.jpg
# 44bdf0f6-6d48-4cc0-bc1d-65100368c027.jpg
# 02cd63d6-4293-44d5-89e1-2235ad2cff93.jpg
# 7aff267a-38f9-4a8d-a30e-18f3acbb9665.jpg
# 6bd945ad-4fdc-4b76-9b80-9b66bef1ec29.jpg
# a31634e5-44f5-44bd-bab4-aa3bd7cb59ee.jpg
# 89edfa97-d78f-4364-b792-a75fb4e2805c.jpg
# dd4b3fb2-5e3c-44bf-a2c2-ec8a6898d325.jpg
# 47a6dfe8-2a04-4763-b525-d2a15b681d02.JPG
# a5e3e2f7-40ae-4813-a99e-27187a8f9e8f.jpg
# 4634b15a-bae9-45d7-9a85-48b067a19b77.jpg
# 3a3b0800-85ff-40b8-aac6-e064c3e14c37.jpg
# 82334bba-c617-4634-beeb-e947deea95e1.jpg
# 937e865a-5bcc-44fb-835f-a37cf4e4aefb.jpg
# 9e9ff881-d724-4715-8a52-58213488450a.jpg
# aaffe076-b370-4feb-84f8-db1cd6bd51a5.jpg
# 979d2a8f-c6cc-4c6b-8c2e-dce5ba5c225d.jpg
# a463d0a2-52f3-4198-87bc-2b3fd7aae230.jpg
# 5ade458e-f900-4b64-bd0c-ede1094184b8.jpg
# 3871e259-4631-4b0d-95a6-bea3e36fa403.jpg
# 4f58132a-49ff-46d1-b225-fe6cf6288134.jpg
# 806c6cf6-ff38-4239-ab79-de14c6a75561.jpg
# 3c87bac0-3a15-4d49-af9a-4bedf468b13a.jpg
# f6a46495-a441-41c9-91c3-ceff1616db88.jpg
# e95030ce-f7a7-4ea6-b4f3-da72363952de.jpg
# 30777161-028a-41c9-b543-03ca0598ba41.jpg
# 4b6c5dae-24e8-456a-91fc-ec6f35c495c0.jpg
# 89904f07-3e1a-4f1c-a661-e1168553e34a.jpg
# 58316362-a8c5-4790-96e3-ca867afdee90.jpg
# 078b7c80-9e0f-451c-a133-02f7174d89f5.jpg
# 7c58fc84-8950-4fdc-b42b-6d50adf0675a.jpg
# 9e785a3d-00db-4d5c-be90-4f56838c232b.jpg
# e858e300-c2e0-4833-bc03-c54bee144ebb.jpg
# d54771ab-2587-49bf-a388-115a4c5ac42f.jpg
# a82da1b9-61d9-44d0-8b9d-ae4e279e0b5a.jpg
# f8c512f0-f37c-4496-9773-40e7ad65caf3.jpg
# 0c69e722-590c-44c4-8ffa-5ed391d5d1c9.jpg
# 30f292fd-7855-441a-af63-8c709c27d81e.jpeg
# d36a4bc1-919a-4314-966e-e13dddf31f08.jpg
# 2bc9ed19-6f86-42b8-a431-e5352ee65afb.png
# 97cc7cc7-4afb-4dd5-aa54-aa2b64e1383f.jpg
# 4a42484b-a615-4f14-b440-8e78de77847c.jpg
# 08dee667-03c9-4b49-8691-aa762a74ce60.jpg
# e834cc98-3d4a-4924-9cc0-ed5463a8aeab.jpg
# ef019454-e0d8-4e16-af40-4b29815fa5e5.jpg
# ddb39113-c6de-4179-a406-c6aaab5032dd.jpg
# 0b58bfdc-c2e8-466c-9e0a-1696800d9843.jpg
# 0c7efcb2-0d0e-4d9a-8f94-0a21cf1e39c0.jpg
# 43f8514c-594c-4e78-8fa0-4c8521503fb4.jpg
# f257b8cc-26b9-47d4-86c9-a9b677dc7ceb.jpg
# 4bc40707-540f-4f27-a91e-4131655346b5.jpg
# c51834ea-9b9a-4cfe-80f7-deee0a1bc738.jpg
# cfa76703-2b06-45b4-a64d-dda50430ebea.jpg
# f6a659cb-9117-4ddb-b239-18ae59ea5370.jpg
# 0a263c84-5a71-418f-a18d-6ebd3fc05f9b.jpg
# f5d11cdd-e5da-4257-a652-a974cb4ed180.jpg
# 40647153-4b7a-42ec-8220-a29259121d51.jpg
# 1c99a4b2-7a81-4dce-9337-42d8f9a62ffb.jpg
# 1653c6ec-3c77-4f51-a9bd-24f835d63d74.jpg
# deaf14c3-01ed-4d35-a727-361370f803eb.jpg
# 0b446dad-691e-43ac-a5e9-b7ef84cff0b0.jpg
# e3df0550-4a99-4f15-a3c2-9e9ea4ada259.jpg
# 71816eae-3911-4097-a5e0-176230a9b469.jpg
# d4e4ab3e-9205-4c98-ac6b-ac0609c17a75.jpg
# af6ede00-7372-4b99-b3cb-5154dc362970.jpg
# 243d3896-cedc-49bd-8bcc-d7f4cd1ea9b2.jpg
# 74fcefb9-5a41-420a-8ca5-835960d77588.jpg
# 9c6f88f2-85d4-4e3c-b774-febee915d911.jpg
# fa103f29-546d-49b5-8b0f-ff47291dbf9c.jpg
# 2c8dc172-83e1-4f0b-ad83-ed70a172214c.jpg
# 8b372cde-3e37-440e-9a73-53df74ebc64a.jpg
# 2dbf9b41-e0c0-480c-b8ce-8e6c3d48edb8.jpg
# baace32a-92dc-4528-b2f5-2088cf2a8bc0.jpg
# 9979961a-abd7-48ef-89f1-bc6874d073a0.jpg
# 86cdd957-b58b-47f4-9d72-37e2facb0854.jpg
# adaf5947-8ee7-47a1-bc95-a7a488bf7cc0.jpg
# d5eaa856-a213-4c07-bb73-155b31857808.jpg
# 461b6691-df0c-4971-a310-711f9a64405f.jpg
# b0bf3311-127f-476f-936f-f368b818a072.jpg
# bfca2315-7a94-4ae4-9aa8-211943374fa5.jpg
# 8142fc27-6aa1-45c4-b518-535b1495445a.jpg
# a35a3b4d-5e7f-4172-b7df-cc7dee918062.jpg
# 129ab557-49d0-467a-9135-69324ae0f9ff.jpg
# 200554cf-367a-4e36-8641-f1fb810f700e.jpg
# 89487597-9578-4c3f-b0ce-477c86ebf74d.jpg
# a2e3c5d8-4bc7-4bfc-bcfe-41c0c368de3d.jpg
# 442f9fce-ede3-488b-a106-c37a41e66c6e.jpg
# 53eb6147-3d0c-418f-aa6a-3cd605b4f7cf.jpg
# 43a71a00-09d0-4372-852a-6278ed3a8ad2.jpg
# c34202c0-9c81-4075-a5f8-51eb0c4c7633.jpg
# 38340521-2cf2-4d37-95c6-feb632fac207.jpg
# d5eef27f-888f-4bde-a8c0-9bab1ec3985e.jpg
# 4bc5b217-dfca-4771-b5d9-5bb6832b2d5e.jpg
# c4d71b58-1649-4fb7-894b-ca46fafd1fd6.jpg
# cb9e976e-6e50-4ebd-9068-063ccf1175c4.jpg
# b4ebd698-5d3d-4825-a8d8-9471ed7696f1.jpg
# 4dc1f95e-f619-4903-9878-c2c7bf8fbbbe.jpg
# 69bd7e7b-530f-4511-803a-1e92676fdda6.jpg
# a2f0f38b-f6b9-4d12-91bb-2319de0c4d8e.jpg
# d8aa0565-0ec0-48f8-af80-3e1b8d72f969.jpg
# 5df83647-009b-453b-a7d0-0155814faabd.jpg
# aacbf559-6c1d-417e-956d-921b718dbe8e.jpg
# 2add75b9-3a3b-40aa-a50c-ed7d9048e661.jpg
# 684e3322-6a77-4c53-a162-9171836b6cac.jpg
# a23d3f45-7c59-44a4-9540-07f87c334132.jpg
# 48a57fab-3c20-4ecc-ad56-060332a8f664.jpg
# a5e69156-7a91-4292-adff-c0e9e443a9d6.jpg
# 30fe625e-5c1f-487d-a64b-2e648f3de60d.jpg
# 259b876e-8a47-4d4d-ac60-00cb80635d2e.jpg
# 254adf6b-92e6-4878-95c7-feac91f30d11.jpg
# 31ce9ea0-f964-4080-998d-5d33808eafae.jpg
# 8b271fd1-32b7-405c-9d14-5c520887c64a.jpg
# 7d0a9f25-2b9f-44fa-8554-87bb0562d7eb.jpeg
# a4e8ad89-c9c4-4c6a-8688-1254bc3f1897.jpg
# fb5a98b8-195c-4aec-b0e0-43e788e472cc.jpg
# 13f3bf3c-75e1-480d-8452-21303b84ce68.jpg
# faff18d2-476a-4283-a923-8a9549e5cb2f.jpg
# 9ace312c-419d-47a8-ac92-857aca2cf8bd.jpg
# d0d823bd-6b4e-4ce6-b1ed-4459a692ae0d.jpg
# 4e30fe9f-f55d-46a7-a42f-d356b290fd39.jpg
# 2945dc2d-b2df-4679-93aa-9d5aca888454.jpg
# 2a310130-5f5e-4896-8137-566e23a14969.jpg
# 5bec48f3-cfa1-4ca4-bb28-c82ded6b3f90.jpg
# 81ab7bb2-5a0a-4028-86c5-482534b0dd3b.png
# 0df6441b-2a75-40cc-a28b-73d2baa29194.jpg
# demi moore
# 0e5d10be-def7-48b5-8eae-b6993b34e0bf.jpg
# 19fd5171-d7b7-48e3-bc18-20d10ce026f0.jpg
# c4f4ec9b-a8c5-4e0c-b62f-78de5f43b29c.jpg
# b21e5cbb-e88a-4ba0-b880-1d717a102988.jpg
# 0ae9faf4-2714-418a-9b23-d69953c45aad.jpg
# 329f51b4-a6a9-4c7f-be4f-cf012ac26dac.jpg
# 64f52815-da28-4b12-a38f-161800772964.jpg
# 5d683f5a-2a30-4d27-8faf-163133c5e389.jpg
# 261ba08d-70ee-4f53-8cf1-1b60555d8035.jpg
# 960d03b7-5f07-4a87-b837-061ad5e7bf65.png
# 7b1f498e-9c11-4e8b-b3ea-72808d87c346.jpg
# c078a262-733a-406e-bb0d-67a2f82ec8fb.jpg
# aa9a44ce-1691-4903-8554-6ad3d9642d33.jpg
# 1f675bdc-fafc-4f18-baa1-b71b256a269c.jpg
# 96d343e7-a877-4efa-bc25-3c758c0ea079.jpg
# 06ee53d1-8f00-4a7f-b5f3-65fb73fb89c2.jpg
# 3257a10f-068b-4230-bdb3-f9baa2e3c057.jpg
# 7d429075-12ba-41d6-b54b-ab1051baae19.jpg
# da09cc4a-ccb3-4103-99d5-d9bf59266996.jpg
# 91545282-f22a-4c12-88a4-73543d1d0b82.jpg
# 10387a20-71af-4f0b-b8c3-5048b3862226.jpg
# 0a7a70ce-67f0-4f24-993c-8fd754728a68.jpg
# eecb6da7-903f-44b6-9c99-80aa4e2e80cb.jpg
# 92952955-25bb-4e0c-8bf6-41b49273a54b.jpg
# ec64c276-9c8c-437a-89e3-a9d1fff12d74.jpg
# 4107aa92-073a-4bdb-a465-b632c5a83b1e.jpg
# a8948810-4e58-420d-82b3-f57808eaa141.jpg
# 7525e8fb-4266-4015-a0db-87fa49dc2c24.jpg
# 002bbff5-43a9-4cea-a2ad-5df75c1e3304.jpg
# 1db4acff-5c10-4d6a-9885-527a40931b42.jpg
# 69222283-4267-4b43-8dc0-f8bfe2feccff.jpg
# d0aef88a-40de-43aa-9585-a257a4491881.jpg
# 8038e1d2-554d-4308-8cba-33a6aa93d02c.jpg
# c75fb840-46ab-455f-9595-c8b08490671f.jpg
# 15388abf-4f9b-4afc-9d54-379aaa072b2d.jpg
# 52e9bd4d-3313-45f1-b897-3a3d6ffe150c.jpeg
# 4b09a264-f409-42e4-8954-5d2673413202.jpg
# 6b57e871-2402-40ce-9163-ddd061162a4c.jpg
# 1624f73e-606c-4937-846c-a60ab0adba11.jpg
# 481b68b8-62ee-45e1-8662-3e9d102698ce.jpg
# 929629c0-c802-45c2-834b-55214e9a6289.jpg
# e88c9dec-aa94-4bf5-8a82-db32656e5400.jpg
# eb07d3bd-d59b-4323-a369-981c2797388f.jpg
# 53419dbd-9719-4da0-b796-422e2247b609.jpg
# dcc3ce50-65d6-44cc-83d5-7d4a2fed94ca.jpg
# 630a5c5a-b2f3-41a5-938d-2e6f4b91ae63.jpg
# 951bea24-8cc8-4465-b490-806e48f27c38.jpg
# a6f553a5-c728-48a1-8200-595b4e96fdc4.jpg
# c4b58c3a-69f3-4b7c-b087-cf95fb94103c.jpg
# c8087a15-9ab8-4ca8-af17-d871253e34bc.jpg
# 4dc8b613-3bd1-44bc-b83f-3e06febe2db3.jpg
# 6b40ca9b-12e9-4704-b0aa-d8e32862806c.jpg
# 260bca7f-c375-4535-b763-92f5456d2fcb.jpg
# e0f8b7ef-1ef2-473e-ae90-619781c179d4.jpg
# 04c0ab61-44dd-444e-acf2-14b81ed2c8c1.jpg
# 8fbdeab1-b36d-4ccd-8c96-7250bf1afc4b.jpg
# 5fadde88-2a79-420b-a049-0c61f7a071ad.jpg
# ea838e5d-7db1-472f-a75a-558f4c458da0.jpg
# 37b258c6-0f01-4f17-ab37-d34ceb728b15.jpg
# 54e5bfb2-010b-40b1-95ef-515c4f814d26.jpg
# a35eaaff-dcb7-4f80-a11b-b17bac1c8e8c.jpg
# 1c8e2900-d490-4484-8b22-e2d4434b807f.jpg
# fed21c3e-e6b3-49b8-9924-b9baf5c0c365.jpg
# 9d4cdfe6-0704-4b06-9b54-f1fbe6dfd73a.jpg
# 1e514604-4317-4f9b-baa6-c1b6ee965506.gif
# f8736266-d186-449d-a3ba-7ad53e2ac0a2.jpg
# f6011afb-973d-4fb0-aa16-97d644f4cba7.jpg
# 1d19bc7e-1965-41bb-836a-f410d52567d8.jpg
# 13e019ef-7100-41d9-9c92-0c189d66dfc0.jpg
# 5cbd7550-fd4a-4d0b-b637-69271e93f5ef.jpg
# afdd06f9-83e5-42f9-bf16-1b1db721088b.jpg
# 053b1864-ae08-47c4-929b-bee2ff521d40.jpg
# c3773c7e-8176-437d-b392-4f9ead12e994.jpg
# 5380fae8-aee6-4de7-b821-3e4646f96409.jpg
# 05ee0855-35b3-451c-bf7d-516af52fb8fe.jpg
# 18345996-067a-4d05-8d55-e8f801ec7dfe.jpg
# e819302c-f637-4903-a980-f684ca9aba5a.jpg
# 144ff971-7ee7-4eea-9363-baafcf22b146.jpg
# 41066d82-c22d-422b-8fbc-20c3264d853f.jpg
# b5677bce-c8e2-423f-a194-8257fb1f9658.jpg
# 09b966e8-cbff-48c6-9712-72e1b2a6b9d0.jpg
# a7bcc111-c966-4403-9a86-5931fbb1dfe6.jpg
# 87081c7f-d480-4e52-9ba2-c361a9b5193e.jpg
# 83f962bb-bdeb-4705-bbd2-1148937a0883.jpg
# 5d0dc85c-541d-406d-80e0-a3b503892805.jpg
# 0471a26d-87e4-4568-a953-22a8445d7575.jpg
# 1c1db06c-61f3-486d-a7f5-6cc9bf428b3c.jpg
# 08917fa1-4f87-40b3-a40b-817731f830c7.jpg
# a361ea57-8d9c-4b43-b767-1de0aa6b68d0.jpg
# 291adbec-7d8c-4abb-a594-e603f5429f66.jpg
# 95abde58-283c-4ad7-bd0e-9148a9b5291e.jpg
# b84e39ab-d16c-49ac-8ea9-f4b50d6ca8df.jpg
# b1b2e476-a474-44c2-abc6-aa88106f687b.jpg
# faf5f63b-0a9c-498f-ba90-9074334a78aa.jpg
# c0e85c17-cfd6-4a82-ab98-c9d38406770a.jpg
# 094a4ddc-5188-46d0-90c4-b3502aba434f.jpg
# 33af4750-84c7-4692-890d-fbcfbb1c10f5.jpg
# bef5d87f-29cb-4a5a-b332-84fb88434d1c.jpg
# 9f0da0aa-09b8-47e2-bb66-43f4f38be8a2.jpg
# 86028bf7-7647-4e6c-9ef5-216904ad481e.jpg
# 530cacfe-fdd2-466c-acc0-d5417d4dfa60.jpg
# 4fd446e5-48a2-40d9-a6a4-a5219b704558.jpg
# aa4384a3-1599-4a58-87da-23984ca3954e.jpg
# b16bbe23-72a6-45ab-9fa0-a50d9acab096.jpg
# dfb9394b-3c44-47d8-9bb3-7fb2ff1a3abd.jpg
# b8f75ab5-6b04-455a-9634-b96e38112c57.jpg
# 9e77d4e1-11b6-4ea8-bf55-bc828423e8b2.jpg
# 40b92212-eed1-4358-a574-4d150d0bdb61.jpg
# ea2595a4-a72b-4a3f-857a-d98a4319fff3.jpg
# 8e85484b-b303-4bf6-98bc-ca610b37ace8.jpg
# efcfed87-1fdd-494d-a46f-1b52e484703b.jpg
# ef4a4b03-10e3-4b70-902d-252647b1b0ba.jpg
# 3166126e-390e-4c3c-97be-9617a8dec3e3.jpg
# 8651ea70-6b47-486c-a2a6-b8d1a5bfe230.jpg
# ed6013cd-0ff9-40f6-b3ed-c3e708340627.jpg
# b6dcc6fd-89e6-4f0f-9a9a-814cb3f87a34.jpg
# 268872dc-d85b-4f4a-9b13-dda4b6d71652.jpg
# 577882a9-f817-442c-ba13-e800c3e263af.jpg
# c48ab1e1-0d9d-469e-a4d9-35a353684893.png
# b0cea8f6-446b-4afb-bf34-7c1a5e67aa49.jpg
# 47f86fcb-c7f8-40d5-866f-e9e65f77e549.jpg
# d77716d4-931e-41b3-8731-6cdff0b17271.jpg
# e381181a-f624-40f9-b65b-9ee98e48e460.jpg
# b0c0b25c-0d81-46b2-acac-e8b9cda213fa.jpg
# fa495ce8-bb3d-40dc-8cc1-2907e0da53e8.jpg
# 132bfbc7-8e48-450d-bb68-65a7ccc294aa.jpg
# 65fda1c9-3b85-4edf-bacc-000dd0def575.jpg
# 13b35a15-e123-42a4-96e8-30a08b243807.jpg
# 0c668567-167f-4e50-b8f8-05b276b7f805.jpg
# f7e971ca-173d-43f1-8a69-bd12a64ce937.jpg
# 12fddbcb-af3a-4894-952b-6615ca662456.jpg
# b6c3ddd3-df2a-4243-b7ce-57390a15750f.jpg
# 7bb40fba-8cce-44bf-9fb2-d402fe28f6b4.jpg
# d8c19b01-e87e-46f5-97b9-2113e7904ae8.jpg
# a9a824b6-f109-434a-96c4-17867544cd65.jpg
# 010a22d9-f54f-4b84-9491-7f0792fe73e3.jpg
# 5b1c4f08-0a59-4fe8-bcfa-74b66bdbb590.jpg
# b12bc684-0850-4ee9-8cf6-c3671c9764e8.jpg
# 26c86bcf-8015-4733-b47c-523d8f50b0da.jpg
# ec54eb69-dd23-405c-91b6-93eba6288506.jpg
# 55ee6881-981b-436b-8589-bb248195c244.png
# 4e544cf7-eac7-4a43-89e4-449cbb6f9723.jpg
# 811d2687-e6b2-4f1a-89c0-f527a2aaeb45.jpg
# a4377b6c-6f58-4d06-92fd-a2a0936fa4a5.jpg
# 582d4536-a7d9-4d3a-853f-6a4805db6fa9.jpg
# 8015eb25-86a0-46cd-a504-73fd1d59dfb5.jpg
# 279130d1-a548-4c96-a26a-6a85d5a23ba8.jpeg
# 7f115744-c480-4a3f-aa0b-9e721441ce2c.jpg
# 1b8e6a4e-a26f-459a-8bf4-52622f651169.jpg
# 41985c6d-c191-478e-af2d-2a271054c956.jpg
# f1e773db-f342-4bd4-addd-d9588a80d292.jpg
# 928a93ea-beae-404f-a9ff-3e46d4f68301.jpg
# d1a7cd25-1f28-4158-9ad7-65e4b2ad7816.jpg
# 8a1f2cdc-f359-4f00-9f51-1a281d1fdb66.jpg
# aa1e47e8-e937-4f80-baad-6c4bca380c17.jpg
# af15c254-cbc5-4f6f-adea-cc19d7a963d8.jpg
# d625bab4-3330-4884-87a5-48de5344a670.jpg
# e14897bc-2c60-4a6c-8475-9d644306291d.jpg
# 543151ff-a29b-4bad-bd72-3027a1b2f507.jpg
# 352bf501-03f9-4b88-a72a-00fcac973a15.jpg
# 0a98d2cf-a7c5-44fe-9eed-04dd604ee8e3.jpg
# 717b1bd2-d4fc-42e0-bb13-723ff358cc7d.jpg
# 57ef77b7-7798-4ff2-91f1-f88bda4f9253.jpg
# 08a41f91-4913-4f6a-ae97-d30c2d81848a.jpg
# 02c73762-dff9-4875-80a3-1838dce5d19c.jpg
# 70210be8-397d-4ecb-b4cb-c8c930d74566.jpg
# 1e663441-4d9c-41b4-ac7d-6eab0ab1a7cc.jpg
# edf47e52-cb2c-45c9-8a0b-aac3950b5f2a.jpg
# 43dd1259-2592-4cd8-99b6-f223631e1637.jpg
# aefe8103-8fc2-483f-879f-96c159bab953.jpg
# d7ea35f7-f093-4f2f-97e3-043ce86dd96d.jpg
# 3e56f1d0-2ac8-4449-8bac-8a931ccc7694.jpg
# 6cf5c275-bc1a-4a94-9026-2db422907791.jpg
# fe97238e-abec-4074-80cb-aae746dca84a.jpg
# 10892d83-c037-4465-aaa0-026b7c23d23a.jpg
# c825a645-7dc3-4e1c-b005-99139d120517.jpg
# 71872905-51ef-4cad-a866-fb16c2aecec6.jpg
# 1f690259-f1f5-441d-8a0b-a0fa70da9ba5.jpg
# 494f9303-0bcb-4209-a449-9458f908587b.jpg
# 1000cd8e-811b-4e2b-a9ed-26492c3bbd55.jpg
# 4a9ae494-a5a4-4765-9e0c-03ff5ec414f1.jpg
# 69311e26-796e-4b11-af01-5a0144b4b969.jpg
# c54bbfb8-6cce-4e9b-9826-9f5da58dfb68.png
# f1a35b6c-d203-4e97-b48f-f44e108ecf50.jpg
# e764b493-10b7-47ce-939c-4f3123a51cf9.jpg
# 9c9c4929-d1e8-44c0-a381-015ced8ec420.jpg
# 6d14cdf6-7f44-4636-be03-12cb232a4670.jpg
# 78991c76-02c9-45b6-bc08-b02bc5d4ffba.jpg
# 6331f0f3-b8e2-42ff-969b-a278c9fae674.jpg
# 482c2aa0-0453-4060-b6a1-acf4d5dad7dd.jpg
# 63e7017f-95c8-4f5b-bdee-c31198c5e3b8.jpg
# 33b74124-c814-4e36-a084-331a49fa6832.jpg
# ba44982e-f293-4e73-b00b-fb5cb42f0e91.jpg
# 55407be4-e88e-43b0-b2c5-f699322e0c70.jpg
# 34432981-344e-44f0-b367-23d144c42776.jpg
# 520ebfb0-5b8b-495f-b759-83ed337893dd.jpg
# cef42f2d-577d-483f-a4ea-27594f616cbd.jpg
# 9497cc65-8f4b-4c69-b9e8-a3370ba18de4.jpg
# 1c48d108-ab31-4414-8883-7841df3a2c20.jpg
# 533a04cf-72bf-4c3b-a727-8cebe4109d29.jpg
# 0fc8317d-9c1b-402b-b575-c541500bdd83.jpeg
# a1220c13-67c8-45bf-870d-551d91793b82.jpg
# 8b8038ed-c574-4061-98f0-d67338d01102.jpg
# d68937d2-940b-4161-a899-6f207df2054c.png
# e9f48536-5404-4ae3-8dec-72c8f27112d4.jpg
# 6ac09530-5822-4bd6-957e-5a6ffec336b4.jpg
# 397fb05e-5a22-4cf7-b617-21584383488d.jpg
# 8329af02-7f71-4085-bb07-cec5fcc66ee1.jpeg
# 7a6c487f-0e1d-421c-9a82-55ebfe5343c2.jpg
# 0cbcf47f-738a-42b1-8fb4-bee62cafbed0.jpg
# 72d12029-dcc0-47ef-b149-24422769447c.jpg
# eaa3cdfc-860c-46a0-9ace-e566fe6e6aa6.jpg
# c89472ee-1943-4753-8df8-63a41305fbfc.jpg
# 341c14d8-a0d2-4f47-93cc-828c3b175df0.jpg
# c5de6954-c22a-4a8d-a90f-6a5417e5c52b.jpg
# 178ea5dd-07f5-457a-bfea-68c8c26e248b.jpg
# 0abdf20d-aa0b-44b0-a8c8-387786e6a610.jpg
# 5b620311-451b-46fb-9a1d-b78b3276de95.jpg
# 577cb16c-7e17-48ba-aafa-b1d111fd5778.jpg
# b02901ea-fcc6-487b-9a34-b1e0562b37c5.jpg
# 27e9cbc2-39dd-4297-a2c9-f9624c86b36a.jpg
# 03dac913-0c69-400e-b41d-98b4b9812552.jpg
# 8816b1b2-a55c-491a-a478-b14cee61fd6b.jpg
# fb6f8107-1de8-4847-8c72-704ecbe3e81f.jpg
# 9e50238c-77d1-4981-bf4a-0294312f59f2.jpg
# 1a6b232c-b124-4d24-acc0-e63c4007c034.jpg
# 61a96903-9259-4446-b1e6-90147053c962.jpg
# 80ec16cc-9e1b-4a66-8799-cb6f296c4ee4.jpg
# e140016a-a0eb-4c3b-a996-77b8d4736e8e.jpg
# fab10f21-7254-49f3-adc3-9e9698317acd.jpg
# 2a6239f4-97d4-46de-9df4-71d631cc5674.jpg
# d245963b-a9ae-420c-9b0e-870dd43116e4.jpg
# 1de0e69d-9b1d-459f-bffb-647ec125eb83.jpg
# a1004256-11f9-4050-ba37-38af04a613da.jpg
# 099bc9b0-44be-41e4-9f77-9158e71a62ea.jpg
# 34fe47c8-f672-43bf-8d10-4460afc8185b.jpg
# edd53098-ea96-4649-9a69-c8807c3cdcdb.jpg
# 839cf867-db3e-426d-981e-db2afb679715.jpg
# 284760b4-d50d-4cc6-a467-19763271dc61.jpg
# 8d73a878-79e8-4c0b-8383-8563caf65100.jpg
# 5afe1959-4818-479c-9f20-0b7fde55cb8f.jpg
# 6ad5041d-82ac-43d0-8e19-8ec10ab65ed5.jpg
# 5b13c571-3b26-4f3d-8372-7b4f7ee06e99.jpg
# 485b8ff9-4bb9-4392-a87b-2b4f7aa66205.jpg
# 5a8bc423-291f-455b-8bc6-7363b4222ba4.jpg
# ed26f8e4-8589-47dc-89b9-85033c1e8916.jpg
# d2bf2ead-c671-4487-bd91-155367a124e2.jpg
# 51b4836d-e552-41ec-aabe-ff16eeb13081.jpg
# 3af51cd5-4dbe-46cd-a74f-cdb8eb0728c4.jpg
# b7df4b3f-57da-4e3e-99c4-47a66d41746a.jpg
# 22da7cfc-c782-400c-94aa-6d0c45f44495.jpg
# 175f47c0-7783-4400-9ca2-03b8d76554a2.jpg
# 5749e548-db5a-45f1-9836-c0518ec99f90.jpg
# fe1f1ee9-3496-4d01-bd32-cd399f54d94e.jpg
# fcc27682-a1dc-464b-b985-57a7e0cf6efe.jpg

# %% [markdown]
# ## Step 2: Train our model

# %% [markdown]
# Some photos might not download correctly which could cause our model training to fail, so we'll remove them:

# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink)
len(failed)
# Out:
# 5

# %% [markdown]
# To train a model, we'll need `DataLoaders`, which is an object that contains a *training set* (the images used to create a model) and a *validation set* (the images used to check the accuracy of a model -- not used during training). In `fastai` we can create that easily using a `DataBlock`, and view sample images from it:

# %%
dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=[Resize(192, method='squish')]
).dataloaders(path, bs=32)

dls.show_batch(max_n=6)

# %% [markdown]
# Here what each of the `DataBlock` parameters means:
#
#     blocks=(ImageBlock, CategoryBlock),
#
# The inputs to our model are images, and the outputs are categories (in this case, "bird" or "forest").
#
#     get_items=get_image_files,
#
# To find all the inputs to our model, run the `get_image_files` function (which returns a list of all image files in a path).
#
#     splitter=RandomSplitter(valid_pct=0.2, seed=42),
#
# Split the data into training and validation sets randomly, using 20% of the data for the validation set.
#
#     get_y=parent_label,
#
# The labels (`y` values) is the name of the `parent` of each file (i.e. the name of the folder they're in, which will be *bird* or *forest*).
#
#     item_tfms=[Resize(192, method='squish')]
#
# Before training, resize each image to 192x192 pixels by "squishing" it (as opposed to cropping it).

# %% [markdown]
# Now we're ready to train our model. The fastest widely used computer vision model is `resnet18`. You can train this in a few minutes, even on a CPU! (On a GPU, it generally takes under 10 seconds...)
#
# `fastai` comes with a helpful `fine_tune()` method which automatically uses best practices for fine tuning a pre-trained model, so we'll use that.

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.032581</td>
#       <td>0.602009</td>
#       <td>0.290000</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.432494</td>
#       <td>0.337983</td>
#       <td>0.170000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.287072</td>
#       <td>0.302423</td>
#       <td>0.100000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.199750</td>
#       <td>0.274813</td>
#       <td>0.100000</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Generally when I run this I see 100% accuracy on the validation set (although it might vary a bit from run to run).
#
# "Fine-tuning" a model means that we're starting with a model someone else has trained using some other dataset (called the *pretrained model*), and adjusting the weights a little bit so that the model learns to recognise your particular dataset. In this case, the pretrained model was trained to recognise photos in *imagenet*, and widely-used computer vision dataset with images covering 1000 categories) For details on fine-tuning and why it's important, check out the [free fast.ai course](https://course.fast.ai/).

# %% [markdown]
# ## Step 3: Use our model (and build your own!)

# %% [markdown]
# Let's see what our model thinks about that bird we downloaded at the start:

# %%
pred = learn.predict(PILImage.create('demi_moore.jpg'))
pred
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('demi moore', tensor(1), tensor([6.6890e-06, 9.9999e-01]))

# %%
is_demi,_,probs = learn.predict(PILImage.create('demi_moore.jpg'))
print(f"This is: {is_demi}.")
print(f"Probability of prediction: {probs[_]:.4f}")
#print(f"Other Prob: {probs[1-_]:.4f}")
#print(f"dummy: {_}")
Image.open('demi_moore.jpg').to_thumb(256,256)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# This is: demi moore.
# Probability of prediction: 1.0000
# <PIL.Image.Image image mode=RGB size=171x256>

# %%
pred = learn.predict(PILImage.create('courtney_cox.jpg'))
pred
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('courtney cox', tensor(0), tensor([0.9951, 0.0049]))

# %%
is_demi,_,probs = learn.predict(PILImage.create('courtney_cox.jpg'))
print(f"This is: {is_demi}.")
print(f"Probability of prediction: {probs[_]:.4f}")
#print(f"Other Prob: {probs[1-_]:.4f}")
#print(f"dummy: {_}")
Image.open('courtney_cox.jpg').to_thumb(256,256)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# This is: courtney cox.
# Probability of prediction: 0.9951
# <PIL.Image.Image image mode=RGB size=186x256>

# %% [markdown]
# Good job, resnet18. :)
#
# So, as you see, in the space of a few years, creating computer vision classification models has gone from "so hard it's a joke" to "trivially easy and free"!
#
# It's not just in computer vision. Thanks to deep learning, computers can now do many things which seemed impossible just a few years ago, including [creating amazing artworks](https://openai.com/dall-e-2/), and [explaining jokes](https://www.datanami.com/2022/04/22/googles-massive-new-language-model-can-explain-jokes/). It's moving so fast that even experts in the field have trouble predicting how it's going to impact society in the coming years.
#
# One thing is clear -- it's important that we all do our best to understand this technology, because otherwise we'll get left behind!

# %% [markdown]
# Now it's your turn. Click "Copy & Edit" and try creating your own image classifier using your own image searches!
#
# If you enjoyed this, please consider clicking the "upvote" button in the top-right -- it's very encouraging to us notebook authors to know when people appreciate our work.
